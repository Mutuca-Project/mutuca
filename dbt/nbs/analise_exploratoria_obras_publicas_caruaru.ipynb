# %% [markdown]
# # Análise Exploratória de Dados - Obras Públicas de Caruaru/PE

# %% [markdown]
# Este notebook apresenta uma análise exploratória completa dos dados de obras públicas extraídos do Portal da Transparência da Prefeitura de Caruaru/PE.
#
# - Autor: Tiago Henrique
# - Data: Novembro 2025
# - Dataset: 419 obras públicas municipais extraídos em 22/11/2025

# %% [markdown]
# ## 1. Carregaento e Inspeção Inicial dos Dados

# %%
import os
import pandas as pd
import numpy as np
import json
from datetime import datetime
import re

# %%
print("="*80)
print("CARREGARMENTO E INSPEÇÃO")
print("="*80)

base_url = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
file_path = 'nbs/data/2026-02-10T02-35-39+00-00.jsonl'
data_path = os.path.join(base_url, file_path)

df = pd.read_json(data_path, lines=True, encoding='utf-8')
df.head()
# Out:
# ================================================================================
# CARREGARMENTO E INSPEÇÃO
# ================================================================================
#                                           source_url  \
# 0  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 1  https://caruaru.pe.gov.br/obras/dispensa-001-2...
# 2  https://caruaru.pe.gov.br/obras/pregao-eletron...
# 3  https://caruaru.pe.gov.br/obras/dispensa-eletr...
# 4  https://caruaru.pe.gov.br/obras/concorrencia-e...
#
#               extraction_date  \
# 0  2026-02-10T02:35:49.327594
# 1  2026-02-10T02:35:51.145569
# 2  2026-02-10T02:35:53.361434
# 3  2026-02-10T02:35:53.369370
# 4  2026-02-10T02:35:54.113170
#
#                                         general_info  \
# 0  {'paired_data': [{'category': 'Modalidade/nº d...
# 1  {'paired_data': [{'category': 'Modalidade/nº d...
# 2  {'paired_data': [{'category': 'Modalidade/nº d...
# 3  {'paired_data': [{'category': 'Modalidade/nº d...
# 4  {'paired_data': [{'category': 'Modalidade/nº d...
#
#                                             contract  \
# 0  {'paired_data': [{'category': 'Nº', 'value': '...
# 1  {'paired_data': [{'category': 'Nº', 'value': '...
# 2  {'paired_data': [{'category': 'Nº', 'value': '...
# 3  {'paired_data': [{'category': 'Nº', 'value': '...
# 4  {'paired_data': [{'category': 'Nº', 'value': '...
#
#                                           contracted  \
# 0  {'paired_data': [{'category': '19/2024', 'valu...
# 1  {'paired_data': [{'category': '012/2024', 'val...
# 2  {'paired_data': [{'category': '075/2024', 'val...
# 3  {'paired_data': [{'category': '172/2025', 'val...
# 4  {'paired_data': [{'category': '089/2025', 'val...
#
#                             fiscal_year_expenditures  \
# 0  {'paired_data': [{'category': 'Valor Médio Acu...
# 1  {'paired_data': [{'category': 'Valor Médio Acu...
# 2  {'paired_data': [{'category': 'Valor Médio Acu...
# 3  {'paired_data': [{'category': 'Valor Médio Acu...
# 4  {'paired_data': [{'category': 'Valor Médio Acu...
#
#                                   contract_amendment  \
# 0  {'paired_data': [{'category': 'Prazo Aditado',...
# 1  {'paired_data': [{'category': 'Prazo Aditado',...
# 2  {'paired_data': [{'category': 'Prazo Aditado',...
# 3  {'paired_data': [{'category': 'Prazo Aditado',...
# 4  {'paired_data': [{'category': 'Prazo Aditado',...
#
#                               cumulative_amount_paid  \
# 0  {'paired_data': [{'category': 'Valor pago acum...
# 1  {'paired_data': [{'category': 'Valor pago acum...
# 2  {'paired_data': [{'category': 'Valor pago acum...
# 3  {'paired_data': [{'category': 'Valor pago acum...
# 4  {'paired_data': [{'category': 'Valor pago acum...
#
#                                        all_documents  \
# 0  {'paired_data': [{'category': 'Projeto Básico'...
# 1  {'paired_data': [{'category': 'Processo na ínt...
# 2  {'paired_data': [{'category': 'Processo na ínt...
# 3  {'paired_data': [{'category': 'Termo de Referê...
# 4  {'paired_data': [{'category': 'Documentos na Í...
#
#                                        work_location  \
# 0  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 1  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 2  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 3  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 4  [https://caruaru.pe.gov.br/wp-content/uploads/...
#
#                                   extraction_summary
# 0  {'total_sections_processed': 8, 'successful_ex...
# 1  {'total_sections_processed': 8, 'successful_ex...
# 2  {'total_sections_processed': 8, 'successful_ex...
# 3  {'total_sections_processed': 8, 'successful_ex...
# 4  {'total_sections_processed': 8, 'successful_ex...

# %% [markdown]
# Abaixo está um exemplo de como os dados são estruturados no dataset bruto.

# %% [markdown]
# ![caruaru_public_works_data_bronze.png](attachment:2d178374-ff57-473a-9132-88918d20a311.png)

# %% [markdown]
# ### 2.1 Funções Auxiliares de Limpeza dos Dados

# %%
def extract_section_pairs(row, section_name):
    """Função genérica para extrair qualquer seção pareada"""
    if pd.isna(row) or "paired_data" not in row:
        return pd.Series({"valor": None, "data": None})

    pairs = row["paired_data"]
    result = {}

    for pair in pairs:
        category = pair.get("category", "").lower()
        value = pair.get("value", "")
        clean_category = re.sub(r'[^\w\s-]', '', category.strip().lower().replace(' ', '_'))
        # Mapeamento específico por seção
        result[f"{section_name}_{category}"] = value

    return pd.Series(result)

# %%
def clean_currency(value):
    """Converte valores monetários para float"""
    if pd.isna(value) or value == "" or value == "-":
        return np.nan

    clean_val = str(value).replace("R$", "").replace(".", "").replace(",", ".").strip()
    try:
        return float(clean_val)
    except:
        return np.nan

# %%
def clean_percentage(value):
    """Converte percentuais para float"""
    if pd.isna(value) or value == "" or value == "-":
        return np.nan
    clena_val = str(value).replace("%", "").replace(",", ".").strip()
    try:
        return float(clena_val)
    except:
        return np.nan

# %%
def parse_date(date_str, format="%d/%m/%Y"):
    """Converte strings para data para datetime"""
    if pd.isna(date_str) or date_str == "" or date_str == "-":
        return pd.NaT
    try:
        return pd.to_datetime(date_str, format=format, errors="coerce")
    except:
        return pd.NaT

# %%
def extract_days(term_text):
    """Extrai o número de dias do texto de prazo"""
    if pd.isna(term_text) or term_text == "" or term_text == "-":
        return np.nan
        
    match = re.search(r"(\d+)\s*dias?", str(term_text), re.IGNORECASE)

    if match:
        return int(match.group(1))

    return np.nan

# %%
def clean_text(text):
    """Limpa e padroniza texto"""
    if pd.isna(text) or text == "":
        return None

    text = str(text).strip()
    text = re.sub(r"\s+", " ", text)
    return text if text and text != "-" else None

# %%
def extract_modality_type(licitacao_text):
    """Extrai o tipo de modalidade de licitação"""
    if pd.isna(licitacao_text) or licitacao_text == "":
        return None

    first_word = str(licitacao_text).split()[0].upper()

    mapping = {
        "PREGÃO": "PREGÃO",
        "PREG": "PREGÃO",
        "CP": "CARTA PROPOSTA",
        "TP": "TOMADA DE PREÇO",
        "TOMADA": "TOMADA DE PREÇO",
        "CONCORRÊNCIA": "CONCORRÊNCIA",
        "CV": "CONVITE",
        "CONVITE": "CONVITE",
        "DISPENSA": "DISPENSA",
        "DISP": "DISPENSA",
        "INEXIGIBILIDADE": "INEXIGIBILIDADE",
    }
    
    return mapping.get(first_word, first_word)

# %%
def extract_document_type(doc_text):
    """Identifica CPF ou CNPJ"""
    if pd.isna(doc_text) or doc_text == "":
        return None

    doc_clean = str(doc_text).replace(".", "").replace("-","").replace("/", "").strip()
    if len(doc_clean) == 11:
        return "CPF"
    elif len(doc_clean) == 14:
        return "CNPJ"
    else:
        return "IRRGULAR"

# %% [markdown]
# ### 2.2 Expansão dos dados aninhados

# %%
# 1. Extrair informações de general_info
def extract_general_info(row): return extract_section_pairs(row, "general_info")
def extract_contract(row): return extract_section_pairs(row, "contract")
def extract_contracted(row): return extract_section_pairs(row, "contracted")
def extract_fiscal_year_expenditures(row): return extract_section_pairs(row, "fiscal_year_expenditures")
def extract_contract_amendment(row): return extract_section_pairs(row, "contract_amendment")
def extract_contract_cumulative_amount_paid(row): return extract_section_pairs(row, "cumulative_amount_paid")
def extract_work_location(row): return extract_section_pairs(row, "work_location")

# %%
general_info_df = df["general_info"].apply(extract_general_info)
contract_df = df["contract"].apply(extract_contract) 
contracted_df = df["contracted"].apply(extract_contracted)

contracted_df = contracted_df.rename(columns={
    "numero_contrato": "numero_contrato_referencia",
    "cnpj_contratada": "cnpj_contratada",
    "razao_social_contratada":"razao_social_contratada",
    "data_inicio_contrato": "data_icicio_contratada",
})
#general_info_df.head()
#contract_df.head()
contracted_df.sample(10)
# Out:
#     contracted_19/2024 contracted_23/07/2024 contracted_012/2024  \
# 163                NaN                   NaN                 NaN
# 358                NaN                   NaN                 NaN
# 40                 NaN                   NaN                 NaN
# 91                 NaN                   NaN                 NaN
# 143                NaN                   NaN                 NaN
# 192                NaN                   NaN                 NaN
# 153                NaN                   NaN                 NaN
# 353                NaN                   NaN                 NaN
# 387                NaN                   NaN                 NaN
# 253                NaN                   NaN                 NaN
#
#     contracted_09/07/2024 contracted_075/2024 contracted_27/06/2024  \
# 163                   NaN                 NaN                   NaN
# 358                   NaN                 NaN                   NaN
# 40                    NaN                 NaN                   NaN
# 91                    NaN                 NaN                   NaN
# 143                   NaN                 NaN                   NaN
# 192                   NaN                 NaN                   NaN
# 153                   NaN                 NaN                   NaN
# 353                   NaN                 NaN                   NaN
# 387                   NaN                 NaN                   NaN
# 253                   NaN                 NaN                   NaN
#
#     contracted_172/2025 contracted_08/07/2025 contracted_089/2025  \
# 163                 NaN                   NaN                 NaN
# 358                 NaN                   NaN                 NaN
# 40                  NaN                   NaN                 NaN
# 91                  NaN                   NaN                 NaN
# 143                 NaN                   NaN                 NaN
# 192                 NaN                   NaN                 NaN
# 153                 NaN                   NaN                 NaN
# 353                 NaN                   NaN                 NaN
# 387                 NaN                   NaN                 NaN
# 253                 NaN                   NaN                 NaN
#
#     contracted_2 meses  ... contracted_075/2018 contracted_09/09/2019  \
# 163                NaN  ...                 NaN                   NaN
# 358                NaN  ...                 NaN                   NaN
# 40                 NaN  ...                 NaN                   NaN
# 91                 NaN  ...                 NaN                   NaN
# 143                NaN  ...                 NaN                   NaN
# 192                NaN  ...                 NaN                   NaN
# 153                NaN  ...                 NaN                   NaN
# 353                NaN  ...                 NaN                   NaN
# 387                NaN  ...                 NaN                   NaN
# 253                NaN  ...                 NaN                   NaN
#
#     contracted_115/2019 contracted_110/2019 contracted_111/2019  \
# 163                 NaN                 NaN                 NaN
# 358                 NaN                 NaN                 NaN
# 40                  NaN                 NaN                 NaN
# 91                  NaN                 NaN                 NaN
# 143                 NaN                 NaN                 NaN
# 192                 NaN                 NaN                 NaN
# 153                 NaN                 NaN                 NaN
# 353                 NaN                 NaN                 NaN
# 387                 NaN                 NaN                 NaN
# 253                 NaN                 NaN                 NaN
#
#     contracted_126/2019 contracted_105/2019 contracted_31/10/2019  \
# 163                 NaN                 NaN                   NaN
# 358                 NaN                 NaN                   NaN
# 40                  NaN                 NaN                   NaN
# 91                  NaN                 NaN                   NaN
# 143                 NaN                 NaN                   NaN
# 192                 NaN                 NaN                   NaN
# 153                 NaN                 NaN                   NaN
# 353                 NaN                 NaN                   NaN
# 387                 NaN                 NaN                   NaN
# 253                 NaN                 NaN                   NaN
#
#     contracted_089/2019 contracted_16/12/2019
# 163                 NaN                   NaN
# 358                 NaN                   NaN
# 40                  NaN                   NaN
# 91                  NaN                   NaN
# 143                 NaN                   NaN
# 192                 NaN                   NaN
# 153                 NaN                   NaN
# 353                 NaN                   NaN
# 387                 NaN                   NaN
# 253                 NaN                   NaN
#
# [10 rows x 657 columns]

# %% [markdown]
# #### 2.2.1 Funções específicas de extração por seções

# %% [markdown]
# ##### Contracted

# %%
# contracted
def extract_contracted(row):
    """
    Padrão:
    - par 0: category = no contrato, value = CNPJ
    - par 1: category = data início, value = razão social
    """

    if row is None or (isinstance(row, float) and pd.isna(row)) or "paired_data" not in row:
        return pd.Series({

            "numero_contrato_referencia": None,
            "cnpj_contratada": None,
            "razao_social_contratada": None,
            "data_icicio_contratada": None,
        })

    pairs = row["paired_data"]
    result = {
        "numero_contrato_referencia": None,
        "cnpj_contratada": None,
        "razao_social_contratada": None,
        "data_icicio_contratada": None,
    }

    if len(pairs) > 0:
        result["numero_contrato_referencia"] = pairs[0].get("category")
        result["cnpj_contratada"] = pairs[0].get("value")

    if len(pairs) > 1:
        result["data_inicio_contratada"] = pairs[1].get("category")
        result["razao_social_contratada"] = pairs[1].get("value")

    return pd.Series(result)

# %%
contracted_df = df["contracted"].apply(extract_contracted)

contracted_df.head()
# Out:
#   numero_contrato_referencia     cnpj_contratada  \
# 0                    19/2024  00.654.704/0001-88
# 1                   012/2024  07.408.234/0001-11
# 2                   075/2024  19.795.706/0001-15
# 3                   172/2025  51.323.527/0001-98
# 4                   089/2025  34.346.587/0001-07
#
#                              razao_social_contratada data_icicio_contratada  \
# 0     A B L ENGENHARIA COMERCIO E REPRESENTACAO LTDA                   None
# 1                    L. & R. SANTOS CONSTRUCOES LTDA                   None
# 2  ENOVE ENGENHARIA, COMERCIO DE MATERIAS ELETRIC...                   None
# 3             PREVENIR EXTINTORES E INSTALAÇÕES LTDA                   None
# 4                ENGETEC SERVICOS DE ENGENHARIA LTDA                   None
#
#   data_inicio_contratada
# 0             23/07/2024
# 1             09/07/2024
# 2             27/06/2024
# 3             08/07/2025
# 4                2 MESES

# %%
contract_df = df["contract"].apply(extract_contract) 
contract_df.head()
# Out:
#   contract_nº contract_data ínicio contract_prazo  \
# 0     19/2024           23/07/2024       12 MESES
# 1    012/2024           09/07/2024       12 MESES
# 2    075/2024           27/06/2024       12 MESES
# 3    172/2025           08/07/2025        2 MESES
# 4    089/2025              2 MESES     226.403,54
#
#   contract_valor contratado (r$) contract_data conclusão / paralisação
# 0                   3.367.764,05                                     -
# 1                     741.995,10                                     -
# 2                  12.000.000,00                                     -
# 3                     116.980,00                                     -
# 4                              -                                   NaN

# %% [markdown]
# ##### Fiscal Year Expenditures

# %%
def extract_fiscal_year_expenditures(row):
    """
    Padrão:
    - Valor Médio Acumulado R$
    - Valor pago Acumulado no peírodo R$
    - Valor pago Acumulado no exercício R$
    """

    if row is None or (isinstance(row, float) and pd.isna(row)) or "paired_data" not in row:
        return pd.Series({
            "valor_medio_acumulado": None,
            "valor_pago_periodo": None,
            "valor_pago_exercicio": None,
        })

    result = {
        "valor_medio_acumulado": None,
        "valor_pago_periodo": None,
        "valor_pago_exercicio": None,
    }
    
    for pair in row["paired_data"]:
        cat = str(pair.get("category", "")).lower()
        val = pair.get("value", "")

        if "valor médio acumulado" in cat or "valor medio acumulado" in cat:
            result["valor_medio_acumulado"] = val

        elif "período" in cat or "periodo" in cat:
            result["valor_pago_periodo"] = val

        elif "exercício" in cat or "exercicio" in cat:
            result["valor_pago_exercicio"] = val

    return pd.Series(result)

# %%
df["fiscal_year_expenditures"]
# Out:
# 0      {'paired_data': [{'category': 'Valor Médio Acu...
# 1      {'paired_data': [{'category': 'Valor Médio Acu...
# 2      {'paired_data': [{'category': 'Valor Médio Acu...
# 3      {'paired_data': [{'category': 'Valor Médio Acu...
# 4      {'paired_data': [{'category': 'Valor Médio Acu...
#                              ...
# 414    {'paired_data': [{'category': 'Valor Médio Acu...
# 415    {'paired_data': [{'category': 'Valor Médio Acu...
# 416    {'paired_data': [{'category': 'Valor Médio Acu...
# 417    {'paired_data': [{'category': 'Valor Médio Acu...
# 418    {'paired_data': [{'category': 'Valor Médio Acu...
# Name: fiscal_year_expenditures, Length: 419, dtype: object

# %%
fiscal_df = df["fiscal_year_expenditures"].apply(extract_fiscal_year_expenditures)
fiscal_df.head()
# Out:
#   valor_medio_acumulado valor_pago_periodo valor_pago_exercicio
# 0            413.074,68         344.629,58           344.629,58
# 1            627.104,97         324.579,24           324.579,24
# 2          5.280.000,00       5.280.000,00         5.280.000,00
# 3                     0                  0                    0
# 4                     0                  0                    0

# %% [markdown]
# ##### Contract Amendment

# %%
amendment_df = df["contract_amendment"].apply(extract_contract_amendment)
amendment_df.sample(10)
# Out:
#     contract_amendment_prazo aditado  \
# 220            29/12/2022 (07 MESES)
# 50                                 -
# 197            22/02/2023 (03 MESES)
# 352            25/12/2020 (18 MESES)
# 54             04/06/2024 (09 MESES)
# 195                                -
# 251            05/05/2022 (15 meses)
# 84                           60 DIAS
# 282            31/12/2021 (04 MESES)
# 267                                -
#
#     contract_amendment_valor aditado acumulado (r$)
# 220                                               -
# 50                                             0,00
# 197                                               -
# 352                                     -385.979,63
# 54                                    R$ 378.281,44
# 195                                      249.930,02
# 251                                      818.325,85
# 84                                                -
# 282                                      759.345,43
# 267                                      234.957,20

# %% [markdown]
# ##### Cumulative Amount Paid

# %%
cumulative_df = df["cumulative_amount_paid"].apply(extract_contract_cumulative_amount_paid)
cumulative_df.head()
# Out:
#   cumulative_amount_paid_valor pago acumulado
# 0                                  344.629,58
# 1                                  324.579,24
# 2                                5.280.000,00
# 3                                           0
# 4                                           0

# %% [markdown]
# ### 2.3 Tratamento dos dados de informações gerais

# %%
general_info_df.columns
# Out:
# Index(['general_info_modalidade/nº da licitação',
#        'general_info_descrição da obra', 'general_info_situação',
#        'general_info_etapa da obra', 'general_info_percentual concluído',
#        'general_info_responsável pela inexecução temporária do objeto',
#        'general_info_motivo',
#        'general_info_data prevista para reinício da obra'],
#       dtype='object')

# %%
general_info_df.columns = [
    "modalidade_licitacao",
    "descricao_obra",
    "situacao",
    "etapa_obra",
    "percentual_concluido",
    "responsavel_inexecucao",
    "motivo_inexecucao",
    "data_prevista_reinicio",
]

general_info_df['descricao_obra'] = general_info_df['descricao_obra'].apply(clean_text)
general_info_df['situacao'] = general_info_df['situacao'].apply(clean_text)
general_info_df['etapa_obra'] = general_info_df['etapa_obra'].apply(clean_text)
general_info_df['responsavel_inexecucao'] = general_info_df['responsavel_inexecucao'].apply(clean_text)
general_info_df['motivo_inexecucao'] = general_info_df['motivo_inexecucao'].apply(clean_text)

# Converte percentual
general_info_df['percentual_concluido'] = general_info_df["percentual_concluido"].apply(clean_percentage)
# Extrai tipo de modalidade
general_info_df['tipo_modalidade'] = general_info_df['modalidade_licitacao'].apply(extract_modality_type)
# Converte data prevista de reinício
general_info_df['data_prevista_reinicio'] = general_info_df['data_prevista_reinicio'].apply(parse_date)


general_info_df.columns
# Out:
# Index(['modalidade_licitacao', 'descricao_obra', 'situacao', 'etapa_obra',
#        'percentual_concluido', 'responsavel_inexecucao', 'motivo_inexecucao',
#        'data_prevista_reinicio', 'tipo_modalidade'],
#       dtype='object')

# %%
# Analisa o rótulo `modalidade_licitação` para definir o tipo da modalidade

# Avaliar todas as variações existentes
modalidade_count = general_info_df['modalidade_licitacao'].value_counts()
modalidade_count.head()
# Out:
# modalidade_licitacao
# CP 017/2019    12
# CP 016/2022    11
# CP 021/2021    10
# CP 025/2019     8
# CP 002/2019     7
# Name: count, dtype: int64

# %%
# Identificar padrão e extrair siglas do inicio de texto

# %%
# Cria categorias de situação
general_info_df['situacao'] = general_info_df['situacao'].map({
   'Concluída': 'CONCLUIDA',
    'em Andamento': 'EM_ANDAMENTO',
    'Contrato Rescindido': 'RESCINDIDA',
    'Paralisada': 'PARALISADA',
})

# %%
# Adicionar na etapa de enriquecimento
# Cria faixas de conclusão
bins = [0, 25, 50, 75, 100]
labals = ['0-25%', '25-50%', '50-75%', '75-100%']

general_info_df['faixa_conclusao'] = pd.cut(
    general_info_df['percentual_concluido'],
    bins=bins,
    labels=labals,
    include_lowest=True
)

general_info_df.head()
# Out:
#                                 modalidade_licitacao  \
# 0              Concorrência Eletrônica nº 90003/2024
# 1                                 Dispensa 0001/2024
# 2  PREGÃO ELETRÔNICO Nº. 006/2023 - Ata de Regist...
# 3  DISPENSA ELETRÔNICO Nº. 90045/2025 - PROCESSO ...
# 4  CONCORRÊNCIA ELETRÔNICA Nº. 90001/2025 - PROCE...
#
#                                       descricao_obra      situacao  \
# 0  Reforma e requalificação do prédio administrat...  EM_ANDAMENTO
# 1  Conclusão da reforma e ampliação da Escola Mun...  EM_ANDAMENTO
# 2  Fornecimento de SISTEMA DE GERAÇÃO DE ENERGIA ...  EM_ANDAMENTO
# 3  Execução dos Serviços Hidráulicos de Combate a...  EM_ANDAMENTO
# 4  Pavimentação e sinalização na Rua Professora D...  EM_ANDAMENTO
#
#                                           etapa_obra  percentual_concluido  \
# 0  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...                 12.27
# 1  OBRA ESTÁ NA FASE DE ACABAMENTOS, EXECUÇÃO DE ...                 84.52
# 2  ESTÃO SENDO INSTALADOS 800,31 KWp, EQUIVALENTE...                 44.00
# 3  Execução dos Serviços Hidráulicos de Combate a...                  6.00
# 4  Pavimentação e sinalização na Rua Professora D...                  6.00
#
#   responsavel_inexecucao motivo_inexecucao data_prevista_reinicio  \
# 0                   None              None                    NaT
# 1                   None              None                    NaT
# 2                   None              None                    NaT
# 3                   None              None                    NaT
# 4                   None              None                    NaT
#
#   tipo_modalidade faixa_conclusao
# 0    CONCORRÊNCIA           0-25%
# 1        DISPENSA         75-100%
# 2          PREGÃO          25-50%
# 3        DISPENSA           0-25%
# 4    CONCORRÊNCIA           0-25%

# %% [markdown]
# ### 2.4 Tratamento dos dados de contrato

# %%
contract_df.columns = [
    'numero_contrato_principal',
    'data_inicio',
    'prazo',
    'valor_contratado',
    'data_conclusao_paralisacao',
]

# %%
# Limpa textos
contract_df['numero_contrato_principal'] = contract_df['numero_contrato_principal'].apply(clean_text)
contract_df['prazo'] = contract_df['prazo'].apply(clean_text)

# %%
# Converte valores monetários
contract_df['valor_contratado'] = contract_df['valor_contratado'].apply(clean_currency)

# %%
# Converte data de inicio
contract_df['data_inicio'] = contract_df['data_inicio'].apply(parse_date)

# %%
contract_df.head()
# Out:
#   numero_contrato_principal data_inicio       prazo  valor_contratado  \
# 0                   19/2024  2024-07-23    12 MESES        3367764.05
# 1                  012/2024  2024-07-09    12 MESES         741995.10
# 2                  075/2024  2024-06-27    12 MESES       12000000.00
# 3                  172/2025  2025-07-08     2 MESES         116980.00
# 4                  089/2025         NaT  226.403,54               NaN
#
#   data_conclusao_paralisacao
# 0                          -
# 1                          -
# 2                          -
# 3                          -
# 4                        NaN

# %% [markdown]
# ### 2.5 Tratamento dos dados de contratados

# %%
contracted_df.sample(10)
# Out:
#     numero_contrato_referencia     cnpj_contratada  \
# 328                   040/2019  17.830.564/0001-54
# 60                   034/20223  26.969.715/0001-40
# 178                   003/2023  19.119.807/0001-76
# 221                   005/2016  00.758.756/0001-02
# 89                    041/2023  00.758.756/0001-02
# 23                    014/2024  35.474.949/0001-08
# 106                   013/2024  02.520.264/0001-00
# 66                    018/2023  25.186.724/0001-00
# 280                   018/2020  08.307.543/0001-68
# 127                   060/2022  11.091.079/0001-20
#
#                            razao_social_contratada data_icicio_contratada  \
# 328  JOSÉ MARCOS DE LIMA INFRAESTRUTURA E SERVIÇOS                   None
# 60                        ECHI ENGENHARIA COMERCIO                   None
# 178              BARCANTI PROJETOS E SERVICOS LTDA                   None
# 221                         CONSTRUTORA ANCAR LTDA                   None
# 89                          CONSTRUTORA ANCAR LTDA                   None
# 23                 LOCAR SANEAMENTO AMBIENTAL LTDA                   None
# 106            CERTEC ESTRUTURAS METÁLICAS LTDA ME                   None
# 66                         LEWANTI ENGENHARIA LTDA                   None
# 280                   OCTAGON EMPREENDIMENTOS LTDA                   None
# 127  AR ENGENHARIA E SERVIÇOS DE CONSTRUÇÃO EIRELI                   None
#
#     data_inicio_contratada
# 328             27/05/2019
# 60              13/07/2023
# 178             03/02/2023
# 221             20/04/2016
# 89              20/11/2023
# 23              03/04/2024
# 106             25/03/2024
# 66              19/04/2023
# 280             01/07/2020
# 127             05/12/2022

# %% [markdown]
# ### 2.6 Tratamento dos dados de despesas do exercícios

# %%
fiscal_df.head()
# Out:
#   valor_medio_acumulado valor_pago_periodo valor_pago_exercicio
# 0            413.074,68         344.629,58           344.629,58
# 1            627.104,97         324.579,24           324.579,24
# 2          5.280.000,00       5.280.000,00         5.280.000,00
# 3                     0                  0                    0
# 4                     0                  0                    0

# %%
# Renomeia as colunas
fiscal_df.columns = [
    'valor_medio_acumulado',
    'valor_pago_periodo',
    'valor_pago_exercicio'
]

# %%
# Converte valores monetários
fiscal_df['valor_medio_acumulado'] = fiscal_df['valor_medio_acumulado'].apply(clean_currency)
fiscal_df['valor_pago_exercicio'] = fiscal_df['valor_pago_exercicio'].apply(clean_currency)
fiscal_df['valor_pago_periodo'] = fiscal_df['valor_pago_periodo'].apply(clean_currency)

# %% [markdown]
# ### 2.7 Tratamento dos dados de aditivos

# %%
amendment_df.head()
# Out:
#   contract_amendment_prazo aditado  \
# 0                                -
# 1                                -
# 2                                -
# 3                                -
# 4                                -
#
#   contract_amendment_valor aditado acumulado (r$)
# 0                                               -
# 1                                               -
# 2                                               -
# 3                                               -
# 4                                               -

# %%
# Renomeia colunas
amendment_df.columns = ['prazo_aditado', 'valor_aditado_acumulado']

# %%
# Limpa textos
amendment_df['prazo_aditado'] = amendment_df['prazo_aditado'].apply(clean_text)

# %%
amendment_df.head()
# Out:
#   prazo_aditado valor_aditado_acumulado
# 0          None                       -
# 1          None                       -
# 2          None                       -
# 3          None                       -
# 4          None                       -

# %%
amendment_df['valor_aditado_acumulado'] = amendment_df['valor_aditado_acumulado'].apply(clean_currency)

# %%
amendment_df.sample(10)
# Out:
#               prazo_aditado  valor_aditado_acumulado
# 273   08/04/2022 (13 MESES)                 35491.69
# 194                12 MESES                456389.21
# 134  1080 dias - 01/09/2025              43227673.66
# 370   17/12/2020 (18 MESES)                      NaN
# 204   19/06/2023 (24 MESES)               1000862.78
# 410   01/11/2020 (12 MESES)                      NaN
# 64    13/03/2025 (24 MESES)                562510.73
# 198                    None               3090105.74
# 58    01/12/2024 (04 MESES)                 32462.05
# 69    22/06/2025 (18 MESES)               3130795.00

# %% [markdown]
# ### 2.8 Tratamento dos dados de valores pagos acumulados

# %%
cumulative_df.head()
# Out:
#   cumulative_amount_paid_valor pago acumulado
# 0                                  344.629,58
# 1                                  324.579,24
# 2                                5.280.000,00
# 3                                           0
# 4                                           0

# %%
# Renomeira a coluna
cumulative_df.columns = ['valor_pago_acumulado']

# %%
cumulative_df['valor_pago_acumulado'] = cumulative_df['valor_pago_acumulado'].apply(clean_currency)

# %%
cumulative_df.head()
# Out:
#    valor_pago_acumulado
# 0             344629.58
# 1             324579.24
# 2            5280000.00
# 3                  0.00
# 4                  0.00

# %% [markdown]
# ### 2.9 Concatenação do DataFrame final

# %%
df_final = pd.concat([
    general_info_df,
    contract_df,
    contracted_df,
    fiscal_df,
    amendment_df,
    cumulative_df,
    df[['work_location', 'source_url', 'extraction_date']]
], axis=1
    
)

# %%
df_final.shape
# Out:
# (419, 29)

# %%
df_final.columns
# Out:
# Index(['modalidade_licitacao', 'descricao_obra', 'situacao', 'etapa_obra',
#        'percentual_concluido', 'responsavel_inexecucao', 'motivo_inexecucao',
#        'data_prevista_reinicio', 'tipo_modalidade', 'faixa_conclusao',
#        'numero_contrato_principal', 'data_inicio', 'prazo', 'valor_contratado',
#        'data_conclusao_paralisacao', 'numero_contrato_referencia',
#        'cnpj_contratada', 'razao_social_contratada', 'data_icicio_contratada',
#        'data_inicio_contratada', 'valor_medio_acumulado', 'valor_pago_periodo',
#        'valor_pago_exercicio', 'prazo_aditado', 'valor_aditado_acumulado',
#        'valor_pago_acumulado', 'work_location', 'source_url',
#        'extraction_date'],
#       dtype='object')

# %% [markdown]
# ### 2.10 Gerando a tabela de documentos PDF

# %% [markdown]
# 1. Gerar um ID para cada contrato único

# %%
import hashlib

def make_obra_id(url: str) -> str:
    return hashlib.sha256(url.encode("utf-8")).hexdigest()[:16] 

df_final["obra_id"] = df_final["source_url"].apply(make_obra_id)

df_final.head()
# Out:
#                                 modalidade_licitacao  \
# 0              Concorrência Eletrônica nº 90003/2024
# 1                                 Dispensa 0001/2024
# 2  PREGÃO ELETRÔNICO Nº. 006/2023 - Ata de Regist...
# 3  DISPENSA ELETRÔNICO Nº. 90045/2025 - PROCESSO ...
# 4  CONCORRÊNCIA ELETRÔNICA Nº. 90001/2025 - PROCE...
#
#                                       descricao_obra      situacao  \
# 0  Reforma e requalificação do prédio administrat...  EM_ANDAMENTO
# 1  Conclusão da reforma e ampliação da Escola Mun...  EM_ANDAMENTO
# 2  Fornecimento de SISTEMA DE GERAÇÃO DE ENERGIA ...  EM_ANDAMENTO
# 3  Execução dos Serviços Hidráulicos de Combate a...  EM_ANDAMENTO
# 4  Pavimentação e sinalização na Rua Professora D...  EM_ANDAMENTO
#
#                                           etapa_obra  percentual_concluido  \
# 0  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...                 12.27
# 1  OBRA ESTÁ NA FASE DE ACABAMENTOS, EXECUÇÃO DE ...                 84.52
# 2  ESTÃO SENDO INSTALADOS 800,31 KWp, EQUIVALENTE...                 44.00
# 3  Execução dos Serviços Hidráulicos de Combate a...                  6.00
# 4  Pavimentação e sinalização na Rua Professora D...                  6.00
#
#   responsavel_inexecucao motivo_inexecucao data_prevista_reinicio  \
# 0                   None              None                    NaT
# 1                   None              None                    NaT
# 2                   None              None                    NaT
# 3                   None              None                    NaT
# 4                   None              None                    NaT
#
#   tipo_modalidade faixa_conclusao  ... valor_medio_acumulado  \
# 0    CONCORRÊNCIA           0-25%  ...             413074.68
# 1        DISPENSA         75-100%  ...             627104.97
# 2          PREGÃO          25-50%  ...            5280000.00
# 3        DISPENSA           0-25%  ...                  0.00
# 4    CONCORRÊNCIA           0-25%  ...                  0.00
#
#   valor_pago_periodo valor_pago_exercicio  prazo_aditado  \
# 0          344629.58            344629.58           None
# 1          324579.24            324579.24           None
# 2         5280000.00           5280000.00           None
# 3               0.00                 0.00           None
# 4               0.00                 0.00           None
#
#   valor_aditado_acumulado valor_pago_acumulado  \
# 0                     NaN            344629.58
# 1                     NaN            324579.24
# 2                     NaN           5280000.00
# 3                     NaN                 0.00
# 4                     NaN                 0.00
#
#                                        work_location  \
# 0  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 1  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 2  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 3  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 4  [https://caruaru.pe.gov.br/wp-content/uploads/...
#
#                                           source_url  \
# 0  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 1  https://caruaru.pe.gov.br/obras/dispensa-001-2...
# 2  https://caruaru.pe.gov.br/obras/pregao-eletron...
# 3  https://caruaru.pe.gov.br/obras/dispensa-eletr...
# 4  https://caruaru.pe.gov.br/obras/concorrencia-e...
#
#               extraction_date           obra_id
# 0  2026-02-10T02:35:49.327594  4a75bc9ecba5793c
# 1  2026-02-10T02:35:51.145569  89ed9a006f29651d
# 2  2026-02-10T02:35:53.361434  d07371eba7e15542
# 3  2026-02-10T02:35:53.369370  bf42b4765e2967c3
# 4  2026-02-10T02:35:54.113170  66c46fed16cd433e
#
# [5 rows x 30 columns]

# %%
all_documents = []

for obra_id, row in df.iterrows():
    obra_url = row["source_url"]
    docs = row["all_documents"]

    # Garante estrutura esperada
    if not isinstance(docs, dict):
        continue

    # Caso novo: se o collector tiver salvado direto a lista em vez do dict completo
    if "paired_data" in docs:
        pares = docs["paired_data"]
    else:
        # fallback: se for diretamente a lista (pouco provável, mas seguro)
        pares = docs

    if not isinstance(pares, list):
        continue

    for pair in pares:
        titulo = pair.get("category")
        url = pair.get("value")

        # pula pares sem URL
        if not url:
            continue

        all_documents.append(
            {
                "obra_id": make_obra_id(row["source_url"]),
                "obra_url": obra_url,
                "documento_titulo": clean_text(titulo),
                "documento_url": str(url).strip(),
            }
        )

documents_df = pd.DataFrame(all_documents)

# Opcional: filtrar só URLs http(s)
#documents_df = documents_df[
#    documents_df["documento_url"].str.startswith("http", na=False)
#]

documents_df.sample(10)
# Out:
#                obra_id                                           obra_url  \
# 2236  2fc0cdf7b615a294  https://caruaru.pe.gov.br/obras/requalificacao...
# 839   c7a8f3da4c52651c  https://caruaru.pe.gov.br/obras/reforma-da-esc...
# 590   d84cb44f8d43984c  https://caruaru.pe.gov.br/obras/cp-015-2023-co...
# 482   6d97c06872f6da6d            https://caruaru.pe.gov.br/obras/112494/
# 1272  23dbe1f70b342536  https://caruaru.pe.gov.br/obras/construcao-de-...
# 1759  23a7525cdda16c81  https://caruaru.pe.gov.br/obras/execucao-dos-s...
# 281   1c430fffa962951a  https://caruaru.pe.gov.br/obras/locacao-montag...
# 834   f6f01106fbef310e  https://caruaru.pe.gov.br/obras/construcao-do-...
# 1129  6141ca76c64f94d7  https://caruaru.pe.gov.br/obras/execucao-de-pa...
# 247   17d9fb8f274863f1  https://caruaru.pe.gov.br/obras/cp-024-2023-co...
#
#                      documento_titulo  \
# 2236                 Encargos Sociais
# 839       Anexo I - Licença Ambiental
# 590                 Composição de BDI
# 482      Cronograma Físico Financeiro
# 1272                Composição de BDI
# 1759  Composições de Custos Unitários
# 281                            Edital
# 834     Composições de Custo Unitário
# 1129            Planilha Orçamentária
# 247       Anexo J - Licença Ambiental
#
#                                           documento_url
# 2236  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 839   https://caruaru.pe.gov.br/wp-content/uploads/2...
# 590   https://caruaru.pe.gov.br/wp-content/uploads/2...
# 482   https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1272  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1759  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 281   https://caruaru.pe.gov.br/wp-content/uploads/2...
# 834   https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1129  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 247   https://caruaru.pe.gov.br/wp-content/uploads/2...

# %% [markdown]
# ##### Criando um hash estável da URL (ids curtos)

# %%
df_final.head()
# Out:
#                                 modalidade_licitacao  \
# 0              Concorrência Eletrônica nº 90003/2024
# 1                                 Dispensa 0001/2024
# 2  PREGÃO ELETRÔNICO Nº. 006/2023 - Ata de Regist...
# 3  DISPENSA ELETRÔNICO Nº. 90045/2025 - PROCESSO ...
# 4  CONCORRÊNCIA ELETRÔNICA Nº. 90001/2025 - PROCE...
#
#                                       descricao_obra      situacao  \
# 0  Reforma e requalificação do prédio administrat...  EM_ANDAMENTO
# 1  Conclusão da reforma e ampliação da Escola Mun...  EM_ANDAMENTO
# 2  Fornecimento de SISTEMA DE GERAÇÃO DE ENERGIA ...  EM_ANDAMENTO
# 3  Execução dos Serviços Hidráulicos de Combate a...  EM_ANDAMENTO
# 4  Pavimentação e sinalização na Rua Professora D...  EM_ANDAMENTO
#
#                                           etapa_obra  percentual_concluido  \
# 0  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...                 12.27
# 1  OBRA ESTÁ NA FASE DE ACABAMENTOS, EXECUÇÃO DE ...                 84.52
# 2  ESTÃO SENDO INSTALADOS 800,31 KWp, EQUIVALENTE...                 44.00
# 3  Execução dos Serviços Hidráulicos de Combate a...                  6.00
# 4  Pavimentação e sinalização na Rua Professora D...                  6.00
#
#   responsavel_inexecucao motivo_inexecucao data_prevista_reinicio  \
# 0                   None              None                    NaT
# 1                   None              None                    NaT
# 2                   None              None                    NaT
# 3                   None              None                    NaT
# 4                   None              None                    NaT
#
#   tipo_modalidade faixa_conclusao  ... valor_medio_acumulado  \
# 0    CONCORRÊNCIA           0-25%  ...             413074.68
# 1        DISPENSA         75-100%  ...             627104.97
# 2          PREGÃO          25-50%  ...            5280000.00
# 3        DISPENSA           0-25%  ...                  0.00
# 4    CONCORRÊNCIA           0-25%  ...                  0.00
#
#   valor_pago_periodo valor_pago_exercicio  prazo_aditado  \
# 0          344629.58            344629.58           None
# 1          324579.24            324579.24           None
# 2         5280000.00           5280000.00           None
# 3               0.00                 0.00           None
# 4               0.00                 0.00           None
#
#   valor_aditado_acumulado valor_pago_acumulado  \
# 0                     NaN            344629.58
# 1                     NaN            324579.24
# 2                     NaN           5280000.00
# 3                     NaN                 0.00
# 4                     NaN                 0.00
#
#                                        work_location  \
# 0  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 1  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 2  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 3  [https://caruaru.pe.gov.br/wp-content/uploads/...
# 4  [https://caruaru.pe.gov.br/wp-content/uploads/...
#
#                                           source_url  \
# 0  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 1  https://caruaru.pe.gov.br/obras/dispensa-001-2...
# 2  https://caruaru.pe.gov.br/obras/pregao-eletron...
# 3  https://caruaru.pe.gov.br/obras/dispensa-eletr...
# 4  https://caruaru.pe.gov.br/obras/concorrencia-e...
#
#               extraction_date           obra_id
# 0  2026-02-10T02:35:49.327594  4a75bc9ecba5793c
# 1  2026-02-10T02:35:51.145569  89ed9a006f29651d
# 2  2026-02-10T02:35:53.361434  d07371eba7e15542
# 3  2026-02-10T02:35:53.369370  bf42b4765e2967c3
# 4  2026-02-10T02:35:54.113170  66c46fed16cd433e
#
# [5 rows x 30 columns]

# %%
df_final[df_final["obra_id"] == "e1889205147d606b"]
# Out:
#     modalidade_licitacao                                     descricao_obra  \
# 241          CP 015/2021  Reforma e ampliação de unidades de ensino, loc...
#
#       situacao  etapa_obra  percentual_concluido responsavel_inexecucao  \
# 241  CONCLUIDA  Finalizada                 90.75                   None
#
#     motivo_inexecucao data_prevista_reinicio tipo_modalidade faixa_conclusao  \
# 241              None                    NaT  CARTA PROPOSTA         75-100%
#
#      ... valor_medio_acumulado valor_pago_periodo valor_pago_exercicio  \
# 241  ...             194488.14                NaN                  NaN
#
#                         prazo_aditado valor_aditado_acumulado  \
# 241  02/10/2022 (30 Dias) - Concluída                42240.12
#
#     valor_pago_acumulado                                      work_location  \
# 241            194488.14  [https://caruaru.pe.gov.br/wp-content/uploads/...
#
#                                             source_url  \
# 241  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
#
#                 extraction_date           obra_id
# 241  2026-02-10T02:41:43.108011  e1889205147d606b
#
# [1 rows x 30 columns]

# %%
documents_df[documents_df["obra_id"] == "e1889205147d606b"]
# Out:
#                obra_id                                           obra_url  \
# 1535  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1536  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1537  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1538  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
#
#      documento_titulo                                      documento_url
# 1535           Edital  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1536         Contrato  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1537   Projeto Básico  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1538           Anexos  https://caruaru.pe.gov.br/wp-content/uploads/2...

# %% [markdown]
# ##### Exemplo de cruzamento

# %%
cols = ["obra_id", "source_url", "cnpj_contratada", "numero_contrato_principal", "situacao", "etapa_obra", "valor_contratado", "data_conclusao_paralisacao",]
documents_df = documents_df.merge(
    df_final[cols],
    on="obra_id",
    how="left")

documents_df.head()
# Out:
#             obra_id                                           obra_url  \
# 0  4a75bc9ecba5793c  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 1  4a75bc9ecba5793c  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 2  4a75bc9ecba5793c  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 3  4a75bc9ecba5793c  https://caruaru.pe.gov.br/obras/concorrencia-n...
# 4  4a75bc9ecba5793c  https://caruaru.pe.gov.br/obras/concorrencia-n...
#
#      documento_titulo                                      documento_url  \
# 0      Projeto Básico  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1              Edital  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 2            Contrato  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 3  Memória de Cálculo  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 4   Licença Ambiental  https://caruaru.pe.gov.br/wp-content/uploads/2...
#
#                                           source_url     cnpj_contratada  \
# 0  https://caruaru.pe.gov.br/obras/concorrencia-n...  00.654.704/0001-88
# 1  https://caruaru.pe.gov.br/obras/concorrencia-n...  00.654.704/0001-88
# 2  https://caruaru.pe.gov.br/obras/concorrencia-n...  00.654.704/0001-88
# 3  https://caruaru.pe.gov.br/obras/concorrencia-n...  00.654.704/0001-88
# 4  https://caruaru.pe.gov.br/obras/concorrencia-n...  00.654.704/0001-88
#
#   numero_contrato_principal      situacao  \
# 0                   19/2024  EM_ANDAMENTO
# 1                   19/2024  EM_ANDAMENTO
# 2                   19/2024  EM_ANDAMENTO
# 3                   19/2024  EM_ANDAMENTO
# 4                   19/2024  EM_ANDAMENTO
#
#                                           etapa_obra  valor_contratado  \
# 0  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...        3367764.05
# 1  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...        3367764.05
# 2  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...        3367764.05
# 3  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...        3367764.05
# 4  OBRA ESTÁ NA FASE DE EXECUÇÃO DE ALVENARIAS E ...        3367764.05
#
#   data_conclusao_paralisacao
# 0                          -
# 1                          -
# 2                          -
# 3                          -
# 4                          -

# %%
documents_df[documents_df["obra_id"] == "e1889205147d606b"]
# Out:
#                obra_id                                           obra_url  \
# 1535  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1536  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1537  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
# 1538  e1889205147d606b  https://caruaru.pe.gov.br/obras/reforma-e-ampl...
#
#      documento_titulo                                      documento_url  \
# 1535           Edital  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1536         Contrato  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1537   Projeto Básico  https://caruaru.pe.gov.br/wp-content/uploads/2...
# 1538           Anexos  https://caruaru.pe.gov.br/wp-content/uploads/2...
#
#                                              source_url     cnpj_contratada  \
# 1535  https://caruaru.pe.gov.br/obras/reforma-e-ampl...  30.651.938/0001-32
# 1536  https://caruaru.pe.gov.br/obras/reforma-e-ampl...  30.651.938/0001-32
# 1537  https://caruaru.pe.gov.br/obras/reforma-e-ampl...  30.651.938/0001-32
# 1538  https://caruaru.pe.gov.br/obras/reforma-e-ampl...  30.651.938/0001-32
#
#      numero_contrato_principal   situacao  etapa_obra  valor_contratado  \
# 1535                  025/2021  CONCLUIDA  Finalizada         172077.08
# 1536                  025/2021  CONCLUIDA  Finalizada         172077.08
# 1537                  025/2021  CONCLUIDA  Finalizada         172077.08
# 1538                  025/2021  CONCLUIDA  Finalizada         172077.08
#
#      data_conclusao_paralisacao
# 1535                 02/09/2022
# 1536                 02/09/2022
# 1537                 02/09/2022
# 1538                 02/09/2022

# %%
# Exporta df_final e documents_df_final para csv
#df_final.to_csv('obras_publicas_dataset.csv', index=False)
#documents_df.to_csv("documents_dataset.csv", index=False)

# %% [markdown]
# ## 3. Análise de qualidade de dados

# %% [markdown]
# ### 3.1. Análise de completude

# %%
from collections import Counter

# %%
def analisar_completude(df):
    """
    Identifica colunas com dados faltantes, nulos ou vazios.
    Retorna uma DataFrame com métricas de qualidade por coluna
    """

    resultado = []

    for coluna in df.columns:
        total = len(df)
        nulos = df[coluna].isna().sum()

        # Para colunas de textos, verifaca vazios
        vazios = 0
        if df[coluna].dtype == 'object':
            vazios = df[coluna].astype(str).apply(
                lambda x: x.strip() in ['', '-', 'NA', 'None']
            ).sum()

    validos = total - nulos - vazios
    pct_completud = (validos / total) * 100

    resultado.append({
        'coluna': coluna,
        'validos': validos,
        'nulos': nulos,
        'vazios': vazios,
        'pct_completude': round(pct_completud, 2)
    })

    return pd.DataFrame(resultado)

# %% [markdown]
# ### 3.2. Detecção de campos misturados

# %%
def detectar_campos_misturados(df, coluna):
    """
    Identifica se uma coluna contém múltiplos tipos de dados minsturados.
    Útil para campos que misturam data + texto narrativo.
    """

    serie = df[coluna].dropna().astype(str)

    # Contar padrões
    tem_datas = serie.str.contains(r'\d{2}/\d{2}/\d{4}', regex=True).sum()
    tem_parenteses = serie.str.contains(r'\([^)]+\)', regex=True).sum()
    tem_uppercase = serie.str.contains(r'[A-Z]{3,}', regex=True).sum()

    # Palavras-chave comuns em obras públicas
    palavras = ['RESCISÃO', 'RESCISAO', 'PARALISAÇÃO', 'PARALISACAO', 'REINICÍCIO', 'REINICIO', 'TERMO', 'UNILATERAL'] 

    palavras_encontradas = {}

    for palavra in palavras:
        count = serie.str.contains(palavra, case=False, na=False).sum()
        if count > 0:
            palavras_encontradas[palavra] = count

    # Calcula o score de mistura
    score = 0
    if tem_datas > 0: score += 20
    if tem_parenteses > 0: score +=30
    if len(palavras_encontradas) > 0: score += 25
    if len(serie.unique()) / len(serie) > 0.5: score += 25

    return {
        'coluna': coluna,
        'score_mistura': score,
        'tem_datas': tem_datas,
        'tem_parenteses': tem_parenteses,
        'palavras_chave': palavras_encontradas,
        'total_valores': len(serie),
        'valores_unicos': len(serie.unique()),
    }

# %% [markdown]
# ### 3.3. Categorização de valores misturados

# %%
def categorizar_campo_data(serie):
    '''
    Categoriza cada valor de um campo de data identificando seu padrão.
    Retorna série com categorias atribuídas.
    '''
    def categorizar(valor):
        if pd.isna(valor) or str(valor).strip() in ['', '-']:
            return 'VAZIO_OU_HIFEN'

        valor_str = str(valor).upper()

        if 'RESCISÃO' in valor_str or 'RESCISAO' in valor_str:
            return 'DATA_COM_TERMO_RESCISAO'
        elif 'PARALISAÇÃO' in valor_str or 'PARALISACAO' in valor_str:
            if 'REINÍCIO' in valor_str or 'REINICIO' in valor_str:
                return 'HISTORICO_COMPLETO'
            else:
                return 'DATA_COM_PARALISACAO'
        elif re.match(r'^\d{2}/\d{2}/\d{4}$', str(valor).strip()):
            return 'DATA_SIMPLES'
        else:
            return 'OUTRO_FORMATO'

    return serie.apply(categorizar)

# %% [markdown]
# ### 3.4. Análise de inconsistências

# %%
def analisar_inconsistencias_status(df):
    '''
    Identifica obras onde status declarado não condiz com indicadores
    de execução física e financeira.
    '''
    inconsistencias = []

    for idx, row in df.iterrows():
        flags = []
        descricoes = []

        situacao = str(row.get('situacao', '')).upper()
        percentual = row.get('percentual_concluido', 0)
        valor_contratado = row.get('valor_contratado', 0)
        valor_pago = row.get('valor_pago_acumulado', 0)

        # Converte percentual se necessário
        if isinstance(percentual, str):
            try:
                percentual = float(percentual.replace('%', '').replace(',', '.'))
            except:
                percentual = 0

        # Calcula execução financeira
        perc_exec_financeira = 0
        if pd.notna(valor_contratado) and pd.notna(valor_pago) and valor_contratado > 0:
            perc_exec_financeira = (valor_pago / valor_contratado) * 100

        # Checa inconsistências
        if 'RESCIND' in situacao:
            if pd.notna(percentual) and percentual >= 95:
                flags.append('FISICA_COMPLETA')
                descricoes.append(f"Rescindida mas {percentual:.1f}% concluída")

            if perc_exec_financeira >= 95:
                flags.append('FINANCEIRA_COMPLETA')
                descricoes.append(f"Rescindida mas {perc_exec_financeira:.1f}% executada")

        if perc_exec_financeira > 150:
            flags.append('VALOR_EXCEDIDO')
            descricoes.append(f"Valor pago >> valor contratado")

        if flags:
            inconsistencias.append({
                'index': idx,
                'numero_contrato': row.get('numero_contrato'),
                'situacao': row.get('situacao'),
                'percentual_concluido': percentual,
                'perc_exec_financeira': perc_exec_financeira,
                'flags': flags,
                'descricoes': descricoes,
                'gravidade': len(flags)
            })

    return pd.DataFrame(inconsistencias)

# %%
print("\n1. ANÁLISE DE COMPLETUDE")

df_completude = analisar_completude(df_final)
colunas_problematicas = df_completude[df_completude['pct_completude'] < 80]
print(f"Colunas problemáticas: {len(colunas_problematicas)}")
print(colunas_problematicas[['coluna', 'pct_completude']])

# 3. Detecta campos misturados
print("\n2. CAMPOS COM DADOS MISTURADOS")
if 'data_conclusao_paralisacao' in df_final.columns:
    resultado_mistura = detectar_campos_misturados(df_final, 'data_conclusao_paralisacao')
    # resultado_mistura = detectar_campos_misturados(df_final, 'data_prevista_reinicio')
    print(f"Score de mistura: {resultado_mistura['score_mistura']}/100")
    print(f"Registros com datas: {resultado_mistura['tem_datas']}")
    print(f"Palavras-chave encontradas: {resultado_mistura['palavras_chave']}")

    # Categoriza valores
    categorias = categorizar_campo_data(df_final['data_conclusao_paralisacao'])
    # categorias = categorizar_campo_data(df_final['data_prevista_reinicio'])
    print("\nDistribuição de formatos:")
    print(categorias.value_counts())

# 4. Identifica inconsistências
print("\n3. INCONSISTÊNCIAS STATUS vs INDICADORES")
df_inconsist = analisar_inconsistencias_status(df_final)
if len(df_inconsist) > 0:
    print(f"Inconsistências detectadas: {len(df_inconsist)} ({len(df_inconsist)/len(df)*100:.1f}%)")
    print("\nCasos mais graves:")
    print(df_inconsist.nlargest(3, 'gravidade')[['numero_contrato', 'gravidade', 'descricoes']])
else:
    print("✓ Nenhuma inconsistência detectada")

# 5. Relatório final
print("\n4. RESUMO EXECUTIVO")
print(f"- Campos misturados: {resultado_mistura.get('tem_datas', 0)} casos")
print(f"- Históricos complexos: {(categorias == 'HISTORICO_COMPLETO').sum()} casos")
print(f"- Inconsistências: {len(df_inconsist)} casos")
print(f"- Dados faltantes: {(categorias == 'VAZIO_OU_HIFEN').sum()} casos")
# Out:
# 1. ANÁLISE DE COMPLETUDE
# Colunas problemáticas: 0
# Empty DataFrame
# Columns: [coluna, pct_completude]
# Index: []
#
# 2. CAMPOS COM DADOS MISTURADOS
# Score de mistura: 100/100
# Registros com datas: 307
# Palavras-chave encontradas: {'RESCISÃO': np.int64(14), 'PARALISAÇÃO': np.int64(96), 'REINICIO': np.int64(1), 'TERMO': np.int64(6), 'UNILATERAL': np.int64(3)}
#
# Distribuição de formatos:
# data_conclusao_paralisacao
# OUTRO_FORMATO              130
# VAZIO_OU_HIFEN             105
# HISTORICO_COMPLETO          78
# DATA_SIMPLES                77
# DATA_COM_PARALISACAO        15
# DATA_COM_TERMO_RESCISAO     14
# Name: count, dtype: int64
#
# 3. INCONSISTÊNCIAS STATUS vs INDICADORES
# Inconsistências detectadas: 47 (11.2%)
#
# Casos mais graves:
#    numero_contrato  gravidade  \
# 40            None          2
# 0             None          1
# 1             None          1
#
#                                            descricoes
# 40  [Rescindida mas 95.9% concluída, Rescindida ma...
# 0                    [Valor pago >> valor contratado]
# 1                    [Valor pago >> valor contratado]
#
# 4. RESUMO EXECUTIVO
# - Campos misturados: 307 casos
# - Históricos complexos: 78 casos
# - Inconsistências: 47 casos
# - Dados faltantes: 105 casos
