# %% [markdown]
# # Análise dos elementos de interesse no portal da Prefeitura de Caruaru

# %% [markdown]
# ```
# data de inicio: 2023-09-21
# data de conclusão:
# ```

# %% [markdown]
# ## Obtendo dados de Obras públicas

# %% [markdown]
# ## Páginas de interesse

# %% [markdown]
# |NOME|URL|IMAGEM EXEMPLO|
# |----|---|-----------|
# |Página inicial|https://caruaru.pe.gov.br/portal-da-transparencia/|<img src="../prefeitura_municipal/img/home_portal_transparencia_prefeitura_caruaru.png"></img>|
# |Seção "Obras_Públicas"|https://caruaru.pe.gov.br/portal-da-transparencia/obras-publicas/|<img src="../prefeitura_municipal/img/secao_obras_publicas_prefeitura_caruaru.png"></img>|
# |Página de buscas por Obras Públicas|https://caruaru.pe.gov.br/portal-da-transparencia/obras-publicas/|<img src="../prefeitura_municipal/img/pagina_obras_publicas_prefeitura_caruaru.png"></img>|
# |Exemplo de Dados de Obras Públicas (conteúdo de um dos cards)|https://caruaru.pe.gov.br/obras/dispensa-003-2024-ct-014-2024-contratacao-direta-de-empresa-especializada-na-prestacao-dos-servicos-de-manejo-dos-residuos-solidos-urbanos-no-municipio-de-caruaru-pe/|<img src="../prefeitura_municipal/img/conteudo_detalhado_obras_prefeitura.png"></img>|

# %% [markdown]
# ## Exploração dos elementos de interesse:

# %% [markdown]
# ### Xpath para obter todos os links para dados de obras públicas
#
# ![xpath](../prefeitura_municipal/img/caminho_para_card_obras.png)
#
# ```
# //section[@class="groupBox contrast"]/a[contains(@class, "box status")]/@href
# ```

# %%
import requests
from parsel import Selector

# %%
url = "https://caruaru.pe.gov.br/portal-da-transparencia/obras-publicas/"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
html_text = response.text
html_selector = Selector(html_text)

urls_obras = html_selector.xpath('//section[@class="groupBox contrast"]/a[contains(@class, "box status")]/@href').getall()

urls_obras
# Out:
# ['https://caruaru.pe.gov.br/obras/dispensa-003-2024-ct-014-2024-contratacao-direta-de-empresa-especializada-na-prestacao-dos-servicos-de-manejo-dos-residuos-solidos-urbanos-no-municipio-de-caruaru-pe/',
#  'https://caruaru.pe.gov.br/obras/preg-eletr-041-2023-ct-040-2023-fornecimento-e-transporte-de-agua-bruta-com-servico-de-irrigacao-atraves-de-caminhoes-pipa-para-fins-de-irrigacao-de-pracas-parques-urbanos-jardins-canteiro/',
#  'https://caruaru.pe.gov.br/obras/cp-012-2023-ct-042-2023-execucao-da-reforma-e-manutencao-dos-cemiterios-publicos-do-municipio-de-caruaru/',
#  'https://caruaru.pe.gov.br/obras/cp-013-2023-ct-038-2023-execucao-de-servicos-de-conservacao-das-estradas-rurais-no-municipio-de-caruaru-pe/',
#  'https://caruaru.pe.gov.br/obras/ct-150-2023-preg-eletr-008-2023-ata-reg-precos-013-2023-locacao-transporte-montagem-instalacao-e-manutencao-desmontagem-de-palco-camarote-camarim-pavilhao-arqui/',
#  'https://caruaru.pe.gov.br/obras/tp-001-2023-mercado-de-carnes-2a-etapa-requalificacao/',
#  'https://caruaru.pe.gov.br/obras/pe-026-2023-contratacao-de-empresa-especializada-em-locacao-de-caminhoes-guindastes-tipo-munk/',
#  'https://caruaru.pe.gov.br/obras/contratacao-de-empresa-especializada-em-locacao-de-caminhoes-guindaste-tipo-munck-com-cesto-incluindo-motorista-manutencao-e-combustivel-para-apoio-as-acoes-de-poda-limpeza-e-de-manutencao-do/',
#  'https://caruaru.pe.gov.br/obras/contratacao-de-empresa-especializada-em-locacao-de-caminhoes-carroceria-tipo-toco-com-operador-e-mao-de-obra-auxiliar-para-apoio-as-acoes-de-poda-e-limpeza-publica-do-municipio/',
#  'https://caruaru.pe.gov.br/obras/prestacao-de-servicos-de-jardinagem-e-manutencao-de-paisagismo-nas-pracas-parques-e-canteiros-do-municipio-de-caruaru-lotes-ii-e-iii/',
#  'https://caruaru.pe.gov.br/obras/locacao-instalacao-manutencao-e-limpeza-de-cabines-sanitarias-quimicas/',
#  'https://caruaru.pe.gov.br/obras/contratacao-de-empresa-especializada-em-engenharia-sanitaria-para-execucao-dos-servicos-de-operacao-do-aterro-sanitario-de-residuos-solidos-urbanos-de-caruaru/',
#  'https://caruaru.pe.gov.br/obras/prestacao-de-servico-de-coleta-e-transporte-de-chorume-do-aterro-sanitario-incluso-a-destinacao-final/',
#  'https://caruaru.pe.gov.br/obras/sevicos-de-limpeza-desobstrucao-e-manutencao-por-viatura-de-succao-de-fossas-septicas-galerias-e-tubulacoes-de-esgotos/',
#  'https://caruaru.pe.gov.br/obras/conservacao-limpeza-capinacao-desassoreamento-e-remocao-de-residuos-solidos-jogados-no-rio-ipojuca-e-nos-canais-que-desembocam-ao-longo-do-rio/',
#  'https://caruaru.pe.gov.br/obras/locacao-montagem-e-desmontagem-e-manutencao-de-estruturas-e-equipamentos/',
#  'https://caruaru.pe.gov.br/obras/prestacao-de-servico-de-remocao-e-transporte-de-residuos-da-construcao-civil/',
#  'https://caruaru.pe.gov.br/obras/contratacao-de-empresa-especializada-na-locacao-instalacao-manutencao-e-limpeza-de-cabines-sanitarias-quimicas/',
#  'https://caruaru.pe.gov.br/obras/execucao-dos-servicos-de-limpeza-urbana/',
#  'https://caruaru.pe.gov.br/obras/cp-004-2023-ct-023-2023-implantacao-de-bueiros-nas-estradas-rurais-do-municipio-de-caruaru-pe/',
#  'https://caruaru.pe.gov.br/obras/cp-026-2023-ct-004-2024-execucao-dos-servicos-de-recapeamento-e-drenagem-na-central-de-abastecimento-de-caruaru-ceaca-em-caruaru-pe/',
#  'https://caruaru.pe.gov.br/obras/cp-024-2023-contrato-0006-2024-execucao-do-recapeamento-asfaltico-e-drenagem-em-diversas-ruas-nos-bairros-indianopolis-e-deputado-jose-antonio-liberato/',
#  'https://caruaru.pe.gov.br/obras/conclusao-da-obra-de-requalificacao-do-patio-da-antiga-estacao-ferroviaria-de-caruaru-pe/',
#  'https://caruaru.pe.gov.br/obras/revitalizacao-do-parque-da-lagoa-no-municipio-de-caruaru-pe-2/']

# %% [markdown]
# ## Obtendo dados das Obras

# %%
obras_page = requests.get(urls_obras[9])

# %%
obras_page_text = obras_page.text
obras_selector = Selector(obras_page_text)
# Obtem todas as categorias (chaves principais) do formulário
keys = obras_selector.xpath('//section[@class="description-obra"]//div[@class="group-title"]/text()').getall()

keys
# Out:
# ['MODALIDADE | Nº DA LICITAÇÃO',
#  'DESCRIÇÃO DA OBRA',
#  'CONVÊNIO',
#  'CONTRATADO',
#  'CONTRATO',
#  'ADITIVO',
#  'DESPESAS DO EXERCÍCIO',
#  'VALOR PAGO ACUMULADO',
#  'SITUAÇÃO',
#  'ETAPA DA OBRA',
#  'PERCENTUAL CONCLUÍDO',
#  'TODOS OS DOCUMENTOS']

# %%
# Obtem todas as subcategorias (chaves aninhadas) do formulário
nested_keys = obras_selector.xpath('//div[@class="row-cards"]/div[@class="row-card"]/div[@class="card-title"]/text()').getall()
# Associa as subcategorias com sua respectiva categoria 
nested_keys
# Out:
# ['Nº',
#  'Concedente',
#  'CPF | CNPJ',
#  'Razão Social',
#  'Nº',
#  'Data ínicio',
#  'Prazo',
#  'Valor Contratado (R$)',
#  'Data Conclusão / Paralisação',
#  'Prazo Aditado',
#  'Valor Aditado Acumulado (R$)',
#  'Valor Médio Acumulado (R$)',
#  'Valor pago Acumulado no período (R$)',
#  'Valor pago Acumulado no exercício (R$)']

# %%
# Obtendo os valores das chaves e chaves aninhadas
retrive_values = obras_selector.xpath('//section[@class="description-obra"]/div[@class="row-details"]//div[@class="card-info"]/text()[normalize-space()]').getall()

retrive_values
# Out:
# ['\n                                    CONCORRÊNCIA  005/2018                                \n                                ',
#  'Prestação de serviços de jardinagem e manutenção de paisagismo nas praças, parques e canteiros do município de Caruaru, LOTES II e III.',
#  '\n                                            -',
#  '\n                                            -',
#  '\n                                            69.954.212/0001-04',
#  "\n                                            VERD'FICA ATIVIDADES PAISAGíSTICAS LTDA EPP",
#  '\n                                            051/2018',
#  '\n                                            28/12/2018',
#  '\n                                            12 MESES',
#  '\n                                            1.606.558,75 ',
#  '-',
#  '\n                                            48 meses',
#  '\n                                            R$ 8.779.146,43',
#  '\n                                            R$ 103.944,63 ',
#  '\n                                            R$ 141.009,02 ',
#  '\n                                            R$ 141.009,02 ',
#  '\n                                    R$ 543.284,38 ',
#  '\n                                    Concluída                                ',
#  '\n                                        Finalizada                                    ',
#  '\n                                        6.19%                                    ']

# %%
import re

value_list = []

for value in retrive_values:
    formated_item = re.sub(r"\s+", " ", value).strip()
    value_list.append(formated_item)

value_list
# Out:
# ['CONCORRÊNCIA 005/2018',
#  'Prestação de serviços de jardinagem e manutenção de paisagismo nas praças, parques e canteiros do município de Caruaru, LOTES II e III.',
#  '-',
#  '-',
#  '69.954.212/0001-04',
#  "VERD'FICA ATIVIDADES PAISAGíSTICAS LTDA EPP",
#  '051/2018',
#  '28/12/2018',
#  '12 MESES',
#  '1.606.558,75',
#  '-',
#  '48 meses',
#  'R$ 8.779.146,43',
#  'R$ 103.944,63',
#  'R$ 141.009,02',
#  'R$ 141.009,02',
#  'R$ 543.284,38',
#  'Concluída',
#  'Finalizada',
#  '6.19%']

# %%
# Restrutua do formulário
form_structure = {
    keys[0]: value_list[0],
    keys[1]: value_list[1],
    keys[2]: {
        nested_keys[0]: value_list[2],
        nested_keys[1]: value_list[3],
    },
    keys[3]:{
        nested_keys[2]: value_list[4],
        nested_keys[3]: value_list[5],
    },
    keys[4]: {
        nested_keys[4]: value_list[6],
        nested_keys[5]: value_list[7],
        nested_keys[6]: value_list[8],
        nested_keys[7]: value_list[9],
        nested_keys[8]: value_list[10],
    },
    keys[5]: {
        nested_keys[9]: value_list[11],
        nested_keys[10]:value_list[12],
    },
    keys[6]: {
        nested_keys[11]:value_list[13],
        nested_keys[12]:value_list[14],
        nested_keys[13]:value_list[15],
    },
    keys[7]:value_list[16],
    keys[8]:value_list[17],
    keys[9]:value_list[18],
    keys[10]:value_list[19],
}

form_structure
# Out:
# {'MODALIDADE | Nº DA LICITAÇÃO': 'CONCORRÊNCIA 005/2018',
#  'DESCRIÇÃO DA OBRA': 'Prestação de serviços de jardinagem e manutenção de paisagismo nas praças, parques e canteiros do município de Caruaru, LOTES II e III.',
#  'CONVÊNIO': {'Nº': '-', 'Concedente': '-'},
#  'CONTRATADO': {'CPF | CNPJ': '69.954.212/0001-04',
#   'Razão Social': "VERD'FICA ATIVIDADES PAISAGíSTICAS LTDA EPP"},
#  'CONTRATO': {'Nº': '051/2018',
#   'Data ínicio': '28/12/2018',
#   'Prazo': '12 MESES',
#   'Valor Contratado (R$)': '1.606.558,75',
#   'Data Conclusão / Paralisação': '-'},
#  'ADITIVO': {'Prazo Aditado': '48 meses',
#   'Valor Aditado Acumulado (R$)': 'R$ 8.779.146,43'},
#  'DESPESAS DO EXERCÍCIO': {'Valor Médio Acumulado (R$)': 'R$ 103.944,63',
#   'Valor pago Acumulado no período (R$)': 'R$ 141.009,02',
#   'Valor pago Acumulado no exercício (R$)': 'R$ 141.009,02'},
#  'VALOR PAGO ACUMULADO': 'R$ 543.284,38',
#  'SITUAÇÃO': 'Concluída',
#  'ETAPA DA OBRA': 'Finalizada',
#  'PERCENTUAL CONCLUÍDO': '6.19%'}

# %% [markdown]
# ## Obtendo os documentos referentes aos contratos e a localização da obra

# %%
docs = obras_selector.xpath('//div[@class="card-info card-info--docs"]/div[@class="attachment"]//p[@class="cardTitle"]/text()').getall()
docs
# Out:
# [' Contrato VERDFICA ', ' Contrato Rio Una ']

# %%
docs_links = obras_selector.xpath('//div[@class="card-info card-info--docs"]/div[@class="attachment"]//div[@class="button"]/a/@href').getall()
docs_links
# Out:
# ['https://caruaru.pe.gov.br/wp-content/uploads/2024/09/TLwC4DWUDNoc_1.-Contrato-51.2018-VERDFICA.pdf',
#  'https://caruaru.pe.gov.br/wp-content/uploads/2024/09/Haixgx9BrAQc_2.-Conrtrato-52.2018-RIO-UNA.pdf']

# %%
documents = {
    keys[11]: {
        docs[0].strip(): docs_links[0].strip(),
        docs[1].strip(): docs_links[1].strip(),
        
    }
}

documents
# Out:
# {'TODOS OS DOCUMENTOS': {'Contrato VERDFICA': 'https://caruaru.pe.gov.br/wp-content/uploads/2024/09/TLwC4DWUDNoc_1.-Contrato-51.2018-VERDFICA.pdf',
#   'Contrato Rio Una': 'https://caruaru.pe.gov.br/wp-content/uploads/2024/09/Haixgx9BrAQc_2.-Conrtrato-52.2018-RIO-UNA.pdf'}}

# %% [markdown]
# ## Obtendo as coordenadas de longitude e latitude do local em que a obra foi realizada

# %%
map_obra_key = obras_selector.xpath('//section[@class="map-obra"]//div[@class="map-obra_title"]/p/text()').get()
map_obra_key
# Out:
# 'Localização da Obra'

# %%
map_obra_values = obras_selector.xpath('//section[@class="map-obra"]//iframe/@src').getall()
map_obra_values
# Out:
# ['https://www.google.com/maps/d/u/1/embed?mid=1KmVwc8T3m_8r4d5xnhUAjcSO2YzB2tI&ehbc=2E312F',
#  'https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3948.2673999544727!2d-35.9784721!3d-8.2761627!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0%3A0xde3987f42b39638e!2sVia%20Parque!5e0!3m2!1spt-BR!2sbr!4v1674657554208!5m2!1spt-BR!2sbr',
#  'https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d15792.71846573763!2d-35.971496!3d-8.284915750000001!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x7a98bba470d6725%3A0xc92afe5abd2ce709!2sPra%C3%A7a%20Teotonio%20Vilela%20-%20Nossa%20Sra.%20das%20Dores%2C%20Caruaru%20-%20PE%2C%2055004-055!5e0!3m2!1spt-BR!2sbr!4v1674657228932!5m2!1spt-BR!2sbr']

# %%
# Extraindo a longitude e latitude do iframe
for iframe_src in map_obra_values:

    pattern = r'2d(-?\d+\.\d+)!3d(-?\d+\.\d+)'
    match = re.search(pattern, iframe_src)

    if match:
        longitude = match.group(1)
        latitude = match.group(2)
        print(f"Latitude: {latitude}, Longitude: {longitude}")
# Out:
# Latitude: -8.2761627, Longitude: -35.9784721
# Latitude: -8.284915750000001, Longitude: -35.971496

# %% [markdown]
# ## Script completo

# %%
import re
import requests
from parsel import Selector

url = "https://caruaru.pe.gov.br/portal-da-transparencia/obras-publicas/"
response = requests.get(url)
html_text = response.text
html_selector = Selector(html_text)

urls_obras = html_selector.xpath('//section[@class="groupBox contrast"]/a[contains(@class, "box status")]/@href').getall()
# Seleciona uma obra como exemplo para extração dos dados
obras_page = requests.get(urls_obras[9])
obras_page_text = obras_page.text
obras_selector = Selector(obras_page_text)
# Obtem todas as categorias (chaves principais) do formulário
keys = obras_selector.xpath('//section[@class="description-obra"]//div[@class="group-title"]/text()').getall()
# Obtem todas as subcategorias (chaves aninhadas) do formulário
nested_keys = obras_selector.xpath('//div[@class="row-cards"]/div[@class="row-card"]/div[@class="card-title"]/text()').getall()
# Obtendo os valores das chaves e chaves aninhadas
retrive_values = obras_selector.xpath('//section[@class="description-obra"]/div[@class="row-details"]//div[@class="card-info"]/text()[normalize-space()]').getall()

value_list = []

for value in retrive_values:
    formated_item = re.sub(r"\s+", " ", value).strip()
    value_list.append(formated_item)

docs = obras_selector.xpath('//div[@class="card-info card-info--docs"]/div[@class="attachment"]//p[@class="cardTitle"]/text()').getall()
docs_links = obras_selector.xpath('//div[@class="card-info card-info--docs"]/div[@class="attachment"]//div[@class="button"]/a/@href').getall()
map_obra_key = obras_selector.xpath('//section[@class="map-obra"]//div[@class="map-obra_title"]/p/text()').get()
map_obra_values = obras_selector.xpath('//section[@class="map-obra"]//iframe/@src').getall()
coordinates = []

# Extraindo a longitude e latitude do iframe
for iframe_src in map_obra_values:

    pattern = r'2d(-?\d+\.\d+)!3d(-?\d+\.\d+)'
    match = re.search(pattern, iframe_src)

    if match:
        longitude = match.group(1)
        latitude = match.group(2)
        coordinates.append({"Latitude": latitude, "Longitude": longitude} )

if not coordinates:
    coordinates = None

# Formulário completo
form_structure = {
    keys[0]: value_list[0],
    keys[1]: value_list[1],
    keys[2]: {
        nested_keys[0]: value_list[2],
        nested_keys[1]: value_list[3],
    },
    keys[3]:{
        nested_keys[2]: value_list[4],
        nested_keys[3]: value_list[5],
    },
    keys[4]: {
        nested_keys[4]: value_list[6],
        nested_keys[5]: value_list[7],
        nested_keys[6]: value_list[8],
        nested_keys[7]: value_list[9],
        nested_keys[8]: value_list[10],
    },
    keys[5]: {
        nested_keys[9]: value_list[11],
        nested_keys[10]:value_list[12],
    },
    keys[6]: {
        nested_keys[11]:value_list[13],
        nested_keys[12]:value_list[14],
        nested_keys[13]:value_list[15],
    },
    keys[7]:value_list[16],
    keys[8]:value_list[17],
    keys[9]:value_list[18],
    keys[10]:value_list[19],
    keys[11]: {
        docs[0].strip(): docs_links[0].strip(),
        docs[1].strip(): docs_links[1].strip(),
    },
    "GEO COORDENADAS DA OBRA": coordinates,
}

form_structure
# Out:
# {'MODALIDADE | Nº DA LICITAÇÃO': 'CONCORRÊNCIA 005/2018',
#  'DESCRIÇÃO DA OBRA': 'Prestação de serviços de jardinagem e manutenção de paisagismo nas praças, parques e canteiros do município de Caruaru, LOTES II e III.',
#  'CONVÊNIO': {'Nº': '-', 'Concedente': '-'},
#  'CONTRATADO': {'CPF | CNPJ': '69.954.212/0001-04',
#   'Razão Social': "VERD'FICA ATIVIDADES PAISAGíSTICAS LTDA EPP"},
#  'CONTRATO': {'Nº': '051/2018',
#   'Data ínicio': '28/12/2018',
#   'Prazo': '12 MESES',
#   'Valor Contratado (R$)': '1.606.558,75',
#   'Data Conclusão / Paralisação': '-'},
#  'ADITIVO': {'Prazo Aditado': '48 meses',
#   'Valor Aditado Acumulado (R$)': 'R$ 8.779.146,43'},
#  'DESPESAS DO EXERCÍCIO': {'Valor Médio Acumulado (R$)': 'R$ 103.944,63',
#   'Valor pago Acumulado no período (R$)': 'R$ 141.009,02',
#   'Valor pago Acumulado no exercício (R$)': 'R$ 141.009,02'},
#  'VALOR PAGO ACUMULADO': 'R$ 543.284,38',
#  'SITUAÇÃO': 'Concluída',
#  'ETAPA DA OBRA': 'Finalizada',
#  'PERCENTUAL CONCLUÍDO': '6.19%',
#  'TODOS OS DOCUMENTOS': {'Contrato VERDFICA': 'https://caruaru.pe.gov.br/wp-content/uploads/2024/09/TLwC4DWUDNoc_1.-Contrato-51.2018-VERDFICA.pdf',
#   'Contrato Rio Una': 'https://caruaru.pe.gov.br/wp-content/uploads/2024/09/Haixgx9BrAQc_2.-Conrtrato-52.2018-RIO-UNA.pdf'},
#  'GEO COORDENADAS DA OBRA': [{'Latitude': '-8.2761627',
#    'Longitude': '-35.9784721'},
#   {'Latitude': '-8.284915750000001', 'Longitude': '-35.971496'}]}
